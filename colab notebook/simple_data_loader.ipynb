# %%
import pandas as pd

# see all the rows and columns completely
pd.set_option('display.max_columns', None)                                      

# ---------------------------------------------
# each dataset has time series of both deaths and cases per county on a daily basis
counties_2020 = pd.read_csv("/content/us-counties-2020.csv")
counties_2021 = pd.read_csv("/content/us-counties-2021.csv")
counties_2022 = pd.read_csv("/content/us-counties-2022.csv")


final_2020 = pd.read_csv("/content/final_df_2020.csv")
final_2021 = pd.read_csv("/content/final_df_2021.csv")
final_2022 = pd.read_csv("/content/final_df_2022.csv")

# %%
#@title {run: 'auto'}
df_name = "final_2020" #@param ["final_2020", "final_2021", "final_2022"]
df = globals()[df_name]
df.head()
# Out:
#          Date   FIPS  Cases  Death  Vaccination  Population
# 0  2020-01-21  53061      1    0.0          0.0    822083.0
# 1  2020-01-22  53061      1    0.0          0.0    822083.0
# 2  2020-01-23  53061      1    0.0          0.0    822083.0
# 3  2020-01-24  53061      1    0.0          0.0    822083.0
# 4  2020-01-25  53061      1    0.0          0.0    822083.0

# %%
final_2020.shape
# Out:
# (876471, 6)

# %%
simple_2020 = final_2020[["Date", "FIPS", "Cases"]]
simple_2020.head()
# Out:
#          Date   FIPS  Cases
# 0  2020-01-21  53061      1
# 1  2020-01-22  53061      1
# 2  2020-01-23  53061      1
# 3  2020-01-24  53061      1
# 4  2020-01-25  53061      1

# %%
date = simple_2020.Date.unique()
# print(date)

# %%
fips_date_cases_2020 = {}

for index, row in simple_2020.iterrows():
  if (row['Date'],row['FIPS']) not in fips_date_cases_2020:
    fips_date_cases_2020[row['Date'], row['FIPS']] = row['Cases']
  else:
    fips_date_cases_2020[row['Date'], row['FIPS']].append(row['Cases'])

# %%
d = {'date': date}
final = pd.DataFrame(data=d)
final.head()
# Out:
#          date
# 0  2020-01-21
# 1  2020-01-22
# 2  2020-01-23
# 3  2020-01-24
# 4  2020-01-25

# %%
final.shape
# Out:
# (346, 1)

# %%
# creation of empty columns
for el in simple_2020.FIPS.unique():
  final[f"{el}"] = None  

final.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   This is separate from the ipykernel package so we can avoid doing imports until
#          date 53061 17031  6059  4013  6037  6085 25025  6075 55025  6073  \
# 0  2020-01-21  None  None  None  None  None  None  None  None  None  None
# 1  2020-01-22  None  None  None  None  None  None  None  None  None  None
# 2  2020-01-23  None  None  None  None  None  None  None  None  None  None
# 3  2020-01-24  None  None  None  None  None  None  None  None  None  None
# 4  2020-01-25  None  None  None  None  None  None  None  None  None  None
#
#   48029 31055  6023  6067  6095 53063 49035  6041  6055  6097 41067 53033  \
# ...

# %%
for i, row in final.iterrows(): # for each date

  print(fips_date_cases_2020[final.date.iloc[i]])
  break
  # print(fips_date_cases_2020[row[i]])


df = pd.DataFrame(matrix.values(), index = pd.MultiIndex.from_tuples(matrix.keys())).unstack(1).fillna(0)
# Out:
# [(53061, 1)]

# %%
# fips = fips_date_cases_2020.keys()
# list_dataframes = []

# for i in fips:
#   dates = []
#   cases = []
#   for el in fips_date_cases_2020[i]:
#     dates.append(el[0])
#     cases.append(el[1])
#   d = {'dates':dates,'cases':cases, 'fips'}
#   df = pd.DataFrame(d)
#   list_dataframes.append(df)
#   break
# Out:
#   File "<ipython-input-43-d010116bb1e9>", line 11
#     f'{i}' = pd.DataFrame(d)
#     ^
# SyntaxError: can't assign to literal

# %%
# # installation
# !git clone https://github.com/TorchSpatiotemporal/tsl.git
# !pip install torch==1.10.1+cu111 torchvision==0.11.2+cu111 torchaudio==0.10.1 -f https://download.pytorch.org/whl/torch_stable.html
# !pip install torch-scatter torch-sparse torch-geometric -f https://data.pyg.org/whl/torch-1.10.1+cu113.html
# !pip install ./tsl

# %%
# # libraries
# import tsl 
# import torch
# import numpy as np

# np.set_printoptions(suppress=True)
# tsl.logger.disabled = True

# %%
# data loading
